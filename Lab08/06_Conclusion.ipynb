# %% [markdown]
# # 🎯 Conclusion

# %% [markdown]
# ### What we have learned
# - Jupyter lab (notebook)
# - Virtual env and .env
# - Intermidiate to Advance Python:
#     - List and dict comprehensions
#     - Generators
#     - Decorators
#     - Type Hints
#     - Special methods (class methods, static methods, ...)
#     - Class and Sub-classes
#     - Pydantic
#     - Async
#     - Scrapers (BeautifulSoup, Scrapy, Selenium)
#     - API
#     - Client Libraries
# - LLM
#     - Neural Networks
#     - OpenAI
#     - HuggingFace
#     - Ollama
#     - Interfaces (Gradio, Streamlit)
#     - Colab
#     - Models (text, voice, image)
#     - Prompt engineering
#     - Tools (custom, web_search, code_interpreter)
#     - RAG (embeddings, vector dbs)
# - Agent
#     - Openai
#     - Langchain
#     - n8n

# %% [markdown]
# ### 📚 Resources:
#
# Sarvin Style Coding:
# - https://www.youtube.com/watch?v=eCyODUip87c&list=PLMbK063QE0JZPS7cACHChuKCcshFUxfrI
#
# Jadi:
# - https://maktabkhooneh.org/course/آموزش-برنامه-نویسی-با-پایتون-مقدماتی-mk346/
# - https://www.aparat.com/v/a738eqa?playlist=71858&refererRef=channel_page
#
# CodingEntrepreneurs:
# - https://www.youtube.com/@CodingEntrepreneurs/playlists
#
# Other:
# - https://learn.deeplearning.ai/
# - https://academy.openai.com/
# - https://www.udemy.com/courses/it-and-software/
# - https://maktabkhooneh.org
#
# More in depth:
# - Sharif-Machine Learning: https://ocw.sharif.ir/course/id/545
# - Standford-Deep Learning: https://www.youtube.com/watch?v=_NLHFoVNlbg&list=PLoROMvodv4rNRRGdS0rBbXOUGA0wjdh1X&index=8

# %% [markdown]
# # 🎉💭🪄 Just imagine and build :)

# %% [markdown]
# ## 📝💬⚙️ Contribute to the course GitHub
# ### pull-request your codes, ideas, fixes, comments…
